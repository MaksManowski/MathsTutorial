# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# t can be: a number, a numpy array, f is a function
def get_coords(t, f):
    return t, f(t)
def euler(t_0, y_0, n, dt, dy): # dy is a function so that dy(1) = grad at t=1
    pass
def euler_t(t, y_0, dy):
    pass

# %% [markdown]
# Markdown cell
#
# $$\frac{\pi}{\theta}$$

# %%
t = np.arange(100)
f = lambda x : x**2
plt.plot(t, f(t))
plt.plot(t, 10000-f(t))

# %%
x = np.arange(100)
y = x**2
plt.plot(x, y)

# %%
x = np.linspace(-10, 10, 1000)
y = 1/(2**0.5)*np.e**(-(x**2))
plt.plot(x, y, '-')

# %%
n = np.arange(45)
theta = n * (3 - np.sqrt(5)) * np.pi
r = 0.1 * np.sqrt(n)
x = r * np.cos(theta)
y = r * np.sin(theta)
circle = plt.Circle((0.0, 0.0), radius=0.75, fc='deepskyblue')
fig, ax = plt.subplots()
ax.add_patch(circle)
ax.axis('scaled')
ax.plot(x,y,color='tomato')
ax.axis('off')
plt.show()
